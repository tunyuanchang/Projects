# %% [markdown]
# ### Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import random
import tensorflow as tf
import shutil
import cv2

from matplotlib import cm
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.preprocessing import image

# %% [markdown]
# ### parameters

# %%
INPUT_DIR = '/content/drive/Shareddrives/MLFinal/data_edge'
CITIES = os.listdir(INPUT_DIR)

# %%
print(f"Total number of cities is {len(os.listdir(INPUT_DIR))}\n")
for city in CITIES:
  PATH = f"{INPUT_DIR}/{city}/"
  print(f"Total number of {city} is {len(os.listdir(PATH))}")
# Out:
# Total number of cities is 4
#
# Total number of taipei is 500
# Total number of london is 500
# Total number of washington is 500
# Total number of bangkok is 500

# %% [markdown]
# ### split data

# %%
SIZE_ = 299
W = 170
H = 125
SHAPE_2D = (SIZE_, SIZE_)
SHAPE_3D = (SIZE_, SIZE_, 3)

# %%
try:
  shutil.rmtree("/tmp/training")
  shutil.rmtree("/tmp/validation")
except:
  pass
try:
  os.mkdir("/tmp/training")
  os.mkdir("/tmp/validation")

except OSError:
  pass

# %%
SPLIT_SIZE = 0.8

# split into train and validation
def split_data(SOURCE, TRAINING, VALIDATION, SPLIT_SIZE):
  files = []
  for filename in os.listdir(SOURCE):
    file = SOURCE + filename
    if os.path.getsize(file) > 0:
      files.append(filename)
    else:
      print(filename, "is zero length, so ignoring!")
  
  shuffled_set = random.sample(files, len(files))
  N = int(SPLIT_SIZE*len(files))

  for i, filename in enumerate(shuffled_set):
    this_file = SOURCE + filename
    destination = lambda i: TRAINING + filename if (i<N) else VALIDATION + filename
    img_ = cv2.imread(this_file)
    #img = img_[H:H+SIZE_,W:W+SIZE_,:] # cut(after)
    img = cv2.resize(img_, SHAPE_2D) # resize(before)
    cv2.imwrite(destination(i), img)

# %%
for city in CITIES:
  SOURCE_DIR = f"{INPUT_DIR}/{city}/"
  TRAINING_DIR = f"/tmp/training/{city}/"
  VALIDATION_DIR = f"/tmp/validation/{city}/"

  # clean & make folder
  try:
    shutil.rmtree(TRAINING_DIR)
    shutil.rmtree(VALIDATION_DIR)
  except:
    pass
  try:
    os.mkdir(TRAINING_DIR)
    os.mkdir(VALIDATION_DIR)
  except:
    pass

  # split data & copy into folder
  split_data(SOURCE_DIR, TRAINING_DIR, VALIDATION_DIR, SPLIT_SIZE)

# %%
for city in CITIES:
  PATH_0 = f"/tmp/training/{city}/"
  PATH_1 = f"/tmp/validation/{city}/"
  print(f"Total number of training {city} is {len(os.listdir(PATH_0))}")
  print(f"Total number of validation {city} is {len(os.listdir(PATH_1))}")
# Out:
# Total number of training taipei is 400
# Total number of validation taipei is 100
# Total number of training london is 400
# Total number of validation london is 100
# Total number of training washington is 400
# Total number of validation washington is 100
# Total number of training bangkok is 400
# Total number of validation bangkok is 100

# %% [markdown]
# ### data preprocessing

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory("/tmp/training", target_size=SHAPE_2D, batch_size=32, class_mode="sparse")
validation_generator = validation_datagen.flow_from_directory("/tmp/validation", target_size=SHAPE_2D, batch_size=1, class_mode="sparse")
# Out:
# Found 1600 images belonging to 4 classes.
# Found 400 images belonging to 4 classes.

# %% [markdown]
# ### pre-trained model
# Xception: update version of InceptionV3
#
# Reference:
# - function: https://keras.io/api/applications/xception/
# - paper: https://arxiv.org/abs/1610.02357

# %%
pre_trained_model = Xception(input_shape=SHAPE_3D, weights="imagenet", include_top=False)

for layer in pre_trained_model.layers:
  layer.trainable = False
#pre_trained_model.summary()

# %%
x = tf.keras.layers.Flatten()(pre_trained_model.output)
x = tf.keras.layers.Dense(units=1024, activation="relu")(x)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Dense(len(CITIES), activation="softmax")(x)

model = Model(pre_trained_model.input, x)

#model.compile(loss="categorical_crossentropy", optimizer=RMSprop, metrics=["accuracy"])
model.compile(loss="sparse_categorical_crossentropy", optimizer=Adam(learning_rate=1e-3), metrics=["sparse_categorical_accuracy"])

# %% [markdown]
# ### model

# %%
history = model.fit(train_generator, steps_per_epoch=50, epochs=15, \
      validation_data=validation_generator)  #step_per_epoch=50
# Out:
# Epoch 1/15
# 50/50 [==============================] - 30s 444ms/step - loss: 20.9285 - sparse_categorical_accuracy: 0.4075 - val_loss: 1.8634 - val_sparse_categorical_accuracy: 0.5100
# Epoch 2/15
# 50/50 [==============================] - 21s 417ms/step - loss: 0.8579 - sparse_categorical_accuracy: 0.6712 - val_loss: 1.0492 - val_sparse_categorical_accuracy: 0.6100
# Epoch 3/15
# 50/50 [==============================] - 20s 402ms/step - loss: 0.5728 - sparse_categorical_accuracy: 0.7844 - val_loss: 0.9485 - val_sparse_categorical_accuracy: 0.6700
# Epoch 4/15
# 50/50 [==============================] - 21s 417ms/step - loss: 0.3343 - sparse_categorical_accuracy: 0.8769 - val_loss: 0.9756 - val_sparse_categorical_accuracy: 0.6625
# Epoch 5/15
# 50/50 [==============================] - 20s 399ms/step - loss: 0.2449 - sparse_categorical_accuracy: 0.9131 - val_loss: 1.1075 - val_sparse_categorical_accuracy: 0.6575
# Epoch 6/15
# 50/50 [==============================] - 21s 418ms/step - loss: 0.1836 - sparse_categorical_accuracy: 0.9406 - val_loss: 1.4083 - val_sparse_categorical_accuracy: 0.6100
# Epoch 7/15
# 50/50 [==============================] - 20s 401ms/step - loss: 0.1424 - sparse_categorical_accuracy: 0.9544 - val_loss: 1.1979 - val_sparse_categorical_accuracy: 0.6900
# Epoch 8/15
# 50/50 [==============================] - 21s 416ms/step - loss: 0.1237 - sparse_categorical_accuracy: 0.9625 - val_loss: 1.0550 - val_sparse_categorical_accuracy: 0.6925
# Epoch 9/15
# 50/50 [==============================] - 20s 401ms/step - loss: 0.0888 - sparse_categorical_accuracy: 0.9762 - val_loss: 1.2469 - val_sparse_categorical_accuracy: 0.6825
# Epoch 10/15
# 50/50 [==============================] - 21s 417ms/step - loss: 0.0660 - sparse_categorical_accuracy: 0.9825 - val_loss: 1.2827 - val_sparse_categorical_accuracy: 0.6950
# Epoch 11/15
# 50/50 [==============================] - 20s 402ms/step - loss: 0.0519 - sparse_categorical_accuracy: 0.9869 - val_loss: 1.3051 - val_sparse_categorical_accuracy: 0.6850
# Epoch 12/15
# 50/50 [==============================] - 21s 418ms/step - loss: 0.0478 - sparse_categorical_accuracy: 0.9887 - val_loss: 1.4347 - val_sparse_categorical_accuracy: 0.6675
# Epoch 13/15
# 50/50 [==============================] - 20s 399ms/step - loss: 0.0483 - sparse_categorical_accuracy: 0.9856 - val_loss: 1.3518 - val_sparse_categorical_accuracy: 0.6725
# Epoch 14/15
# 50/50 [==============================] - 21s 419ms/step - loss: 0.0287 - sparse_categorical_accuracy: 0.9956 - val_loss: 1.4329 - val_sparse_categorical_accuracy: 0.6575
# Epoch 15/15
# 50/50 [==============================] - 20s 401ms/step - loss: 0.0318 - sparse_categorical_accuracy: 0.9925 - val_loss: 1.5144 - val_sparse_categorical_accuracy: 0.6725

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Xception model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %%
plt.plot(history.history['sparse_categorical_accuracy'])
plt.plot(history.history['val_sparse_categorical_accuracy'])
plt.title('Xception model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='lower right')
plt.show()

# %% [markdown]
# ## Grad-CAM
# Grad-CAM: Visual Explanations from Deep Networks via Gradient-based Localization
#
# Reference:
# - example: https://keras.io/examples/vision/grad_cam/
# - paper: https://arxiv.org/abs/1610.02391

# %%
last_conv_layer_name = "block14_sepconv2_act" # depends on the model (use model.summary() to see)

# %%
def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index):
  grad_model = Model([model.inputs], [model.get_layer(last_conv_layer_name).output, model.output])

  with tf.GradientTape() as tape:
    last_conv_layer_output, preds = grad_model(img_array)
    class_channel = preds[:, pred_index]

  grads = tape.gradient(class_channel, last_conv_layer_output)
  pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

  last_conv_layer_output = last_conv_layer_output[0]
  heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
  heatmap = tf.squeeze(heatmap)

  heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)

  heatmap = np.uint8(255 * heatmap.numpy())

  jet = cm.get_cmap("jet")
  jet_colors = jet(np.arange(256))[:, :3]
  jet_heatmap = jet_colors[heatmap]

  jet_heatmap = image.array_to_img(jet_heatmap).resize(SHAPE_2D)
  jet_heatmap = image.img_to_array(jet_heatmap)

  return jet_heatmap

# %% [markdown]
# ### Prediction

# %%
from IPython.display import display

# %%
class_map = train_generator.class_indices
classes = []
for key in class_map.keys():
  classes.append(key)

alpha = 0.8

def predict_image(filename, model, PRINT):
  img_ = image.load_img(filename, target_size=SHAPE_2D)
  img_array = image.img_to_array(img_)
  img_processed = np.expand_dims(img_array / 255., axis=0)

  prediction = model.predict(img_processed, verbose=0)
  index = np.argmax(prediction)

  if PRINT:
    heatmap = make_gradcam_heatmap(img_processed, model, last_conv_layer_name, index)

    # Superimpose the heatmap on original image
    vistualize_img = heatmap * alpha + img_array
    vistualize_img = image.array_to_img(vistualize_img)

    display(img_, vistualize_img)
  return str(classes[index])

# %%
print(class_map)
# Out:
# {'bangkok': 0, 'london': 1, 'taipei': 2, 'washington': 3}

# %%
PRINT = False
for city in classes:
  PATH0 = f"/tmp/training/{city}"
  d0 = {i:0 for i in classes}
  for x in os.listdir(PATH0):
    pred = predict_image(f"{PATH0}/{x}", model, PRINT)
    d0[pred] += 1

  PATH1 = f"/tmp/validation/{city}"
  d1 = {i:0 for i in classes}
  for x in os.listdir(PATH1):
    pred = predict_image(f"{PATH1}/{x}", model, PRINT)
    d1[pred] += 1
  
  d0 = dict(sorted(d0.items(), key=lambda i:i[1], reverse=True))
  d1 = dict(sorted(d1.items(), key=lambda i:i[1], reverse=True))
  l0 = len(os.listdir(PATH0))
  l1 = len(os.listdir(PATH1))
  print(f"training of {city}:", d0)
  print(f"validation of {city}:", d1)
  print(f"accuracy of {city}: {(d0[city])/l0:.3f} / {(d1[city])/l1:.3f} / {(d0[city]+d1[city])/(l0+l1):.3f}\n")
# Out:
# training of bangkok: {'bangkok': 399, 'washington': 1, 'london': 0, 'taipei': 0}
# validation of bangkok: {'bangkok': 47, 'taipei': 23, 'london': 18, 'washington': 12}
# accuracy of bangkok: 0.998 / 0.470 / 0.892
#
# training of london: {'london': 400, 'bangkok': 0, 'taipei': 0, 'washington': 0}
# validation of london: {'london': 74, 'washington': 13, 'taipei': 11, 'bangkok': 2}
# accuracy of london: 1.000 / 0.740 / 0.948
#
# training of taipei: {'taipei': 400, 'bangkok': 0, 'london': 0, 'washington': 0}
# validation of taipei: {'taipei': 70, 'washington': 15, 'london': 11, 'bangkok': 4}
# accuracy of taipei: 1.000 / 0.700 / 0.940
#
# training of washington: {'washington': 400, 'bangkok': 0, 'london': 0, 'taipei': 0}
# validation of washington: {'washington': 78, 'london': 10, 'bangkok': 6, 'taipei': 6}
# accuracy of washington: 1.000 / 0.780 / 0.956

# %% [markdown]
# ### Test

# %%
ans = 0
iter = 5
for i in range(iter):
  city = random.choice(classes)
  PATH = f"{INPUT_DIR}/{city}"
  x = random.choice(os.listdir(PATH))
  pred = predict_image(f"{PATH}/{x}", model, True)
  if city == pred: ans += 1
  print(f"ground truth of {city}/{x}.jpg: {city}", city == pred)

print(f"{ans}/{iter}")
# Out:
# <ipython-input-17-570f78cd06b2>:19: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   jet = cm.get_cmap("jet")
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7F65402D1550>
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7F65445DB970>
# ground truth of london/460.jpg.jpg: london True
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7F65645482E0>
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7F6544224040>
# ground truth of washington/103.jpg.jpg: washington True
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7F6544224040>
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7F65644DBFA0>
# ground truth of washington/95.jpg.jpg: washington True
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7F65402563A0>
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7F65402D3550>
# ground truth of bangkok/73.jpg.jpg: bangkok False
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7F65416AB400>
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7F6564366550>
# ground truth of washington/484.jpg.jpg: washington True
# 4/5

# %% [markdown]
# ### Check

# %%
PRINT = False
for city in classes:
  PATH0 = f"/tmp/training/{city}"
  for x in os.listdir(PATH0):
    pred = predict_image(f"{PATH0}/{x}", model, PRINT)
    if city != pred:
      print(f"{PATH0}/{x}: False, {pred}")
  
  PATH1 = f"/tmp/validation/{city}"
  d1 = {i:0 for i in classes}
  for x in os.listdir(PATH1):
    pred = predict_image(f"{PATH1}/{x}", model, PRINT)
    if city != pred:
      print(f"{PATH1}/{x}: False, {pred}")
# Out:
# /tmp/training/bangkok/323.jpg: False, washington
# /tmp/validation/bangkok/211.jpg: False, washington
# /tmp/validation/bangkok/491.jpg: False, taipei
# /tmp/validation/bangkok/27.jpg: False, london
# /tmp/validation/bangkok/486.jpg: False, london
# /tmp/validation/bangkok/35.jpg: False, washington
# /tmp/validation/bangkok/12.jpg: False, washington
# /tmp/validation/bangkok/443.jpg: False, london
# /tmp/validation/bangkok/145.jpg: False, washington
# /tmp/validation/bangkok/431.jpg: False, taipei
# /tmp/validation/bangkok/105.jpg: False, london
# /tmp/validation/bangkok/78.jpg: False, taipei
# /tmp/validation/bangkok/317.jpg: False, washington
# /tmp/validation/bangkok/84.jpg: False, taipei
# /tmp/validation/bangkok/294.jpg: False, taipei
# /tmp/validation/bangkok/437.jpg: False, taipei
# /tmp/validation/bangkok/320.jpg: False, washington
# /tmp/validation/bangkok/79.jpg: False, london
# /tmp/validation/bangkok/121.jpg: False, taipei
# /tmp/validation/bangkok/218.jpg: False, taipei
# /tmp/validation/bangkok/72.jpg: False, london
# /tmp/validation/bangkok/83.jpg: False, taipei
# /tmp/validation/bangkok/390.jpg: False, taipei
# /tmp/validation/bangkok/97.jpg: False, taipei
# /tmp/validation/bangkok/484.jpg: False, taipei
# /tmp/validation/bangkok/364.jpg: False, taipei
# /tmp/validation/bangkok/379.jpg: False, washington
# /tmp/validation/bangkok/450.jpg: False, taipei
# /tmp/validation/bangkok/188.jpg: False, london
# /tmp/validation/bangkok/260.jpg: False, washington
# /tmp/validation/bangkok/306.jpg: False, london
# /tmp/validation/bangkok/374.jpg: False, london
# /tmp/validation/bangkok/106.jpg: False, london
# /tmp/validation/bangkok/246.jpg: False, london
# /tmp/validation/bangkok/308.jpg: False, washington
# /tmp/validation/bangkok/233.jpg: False, taipei
# /tmp/validation/bangkok/312.jpg: False, washington
# /tmp/validation/bangkok/8.jpg: False, london
# /tmp/validation/bangkok/369.jpg: False, london
# /tmp/validation/bangkok/275.jpg: False, taipei
# /tmp/validation/bangkok/172.jpg: False, taipei
# /tmp/validation/bangkok/493.jpg: False, london
# /tmp/validation/bangkok/392.jpg: False, washington
# /tmp/validation/bangkok/322.jpg: False, taipei
# /tmp/validation/bangkok/344.jpg: False, london
# /tmp/validation/bangkok/448.jpg: False, taipei
# /tmp/validation/bangkok/413.jpg: False, taipei
# /tmp/validation/bangkok/52.jpg: False, london
# /tmp/validation/bangkok/478.jpg: False, taipei
# /tmp/validation/bangkok/137.jpg: False, washington
# /tmp/validation/bangkok/7.jpg: False, london
# /tmp/validation/bangkok/232.jpg: False, taipei
# /tmp/validation/bangkok/480.jpg: False, london
# /tmp/validation/bangkok/376.jpg: False, taipei
# /tmp/validation/london/23.jpg: False, washington
# /tmp/validation/london/443.jpg: False, washington
# /tmp/validation/london/337.jpg: False, washington
# /tmp/validation/london/164.jpg: False, taipei
# /tmp/validation/london/320.jpg: False, taipei
# /tmp/validation/london/123.jpg: False, washington
# /tmp/validation/london/17.jpg: False, bangkok
# /tmp/validation/london/73.jpg: False, taipei
# /tmp/validation/london/128.jpg: False, washington
# /tmp/validation/london/54.jpg: False, bangkok
# /tmp/validation/london/291.jpg: False, taipei
# /tmp/validation/london/202.jpg: False, taipei
# /tmp/validation/london/1.jpg: False, taipei
# /tmp/validation/london/208.jpg: False, taipei
# /tmp/validation/london/39.jpg: False, washington
# /tmp/validation/london/425.jpg: False, taipei
# /tmp/validation/london/322.jpg: False, washington
# /tmp/validation/london/166.jpg: False, taipei
# /tmp/validation/london/156.jpg: False, washington
# /tmp/validation/london/276.jpg: False, washington
# /tmp/validation/london/319.jpg: False, taipei
# /tmp/validation/london/299.jpg: False, washington
# /tmp/validation/london/353.jpg: False, washington
# /tmp/validation/london/494.jpg: False, washington
# /tmp/validation/london/288.jpg: False, washington
# /tmp/validation/london/113.jpg: False, taipei
# /tmp/validation/taipei/244.jpg: False, bangkok
# /tmp/validation/taipei/109.jpg: False, washington
# /tmp/validation/taipei/64.jpg: False, bangkok
# /tmp/validation/taipei/226.jpg: False, london
# /tmp/validation/taipei/67.jpg: False, washington
# /tmp/validation/taipei/53.jpg: False, london
# /tmp/validation/taipei/105.jpg: False, washington
# /tmp/validation/taipei/313.jpg: False, washington
# /tmp/validation/taipei/117.jpg: False, washington
# /tmp/validation/taipei/123.jpg: False, london
# /tmp/validation/taipei/378.jpg: False, london
# /tmp/validation/taipei/474.jpg: False, london
# /tmp/validation/taipei/195.jpg: False, london
# /tmp/validation/taipei/49.jpg: False, london
# /tmp/validation/taipei/484.jpg: False, washington
# /tmp/validation/taipei/231.jpg: False, london
# /tmp/validation/taipei/452.jpg: False, washington
# /tmp/validation/taipei/56.jpg: False, washington
# /tmp/validation/taipei/311.jpg: False, washington
# /tmp/validation/taipei/15.jpg: False, washington
# /tmp/validation/taipei/451.jpg: False, washington
# /tmp/validation/taipei/194.jpg: False, washington
# /tmp/validation/taipei/31.jpg: False, washington
# /tmp/validation/taipei/478.jpg: False, washington
# /tmp/validation/taipei/213.jpg: False, london
# /tmp/validation/taipei/193.jpg: False, bangkok
# /tmp/validation/taipei/80.jpg: False, bangkok
# /tmp/validation/taipei/353.jpg: False, london
# /tmp/validation/taipei/154.jpg: False, washington
# /tmp/validation/taipei/498.jpg: False, london
# /tmp/validation/washington/27.jpg: False, london
# /tmp/validation/washington/270.jpg: False, london
# /tmp/validation/washington/185.jpg: False, bangkok
# /tmp/validation/washington/370.jpg: False, london
# /tmp/validation/washington/38.jpg: False, london
# /tmp/validation/washington/464.jpg: False, london
# /tmp/validation/washington/132.jpg: False, taipei
# /tmp/validation/washington/84.jpg: False, bangkok
# /tmp/validation/washington/94.jpg: False, bangkok
# /tmp/validation/washington/254.jpg: False, taipei
# /tmp/validation/washington/10.jpg: False, taipei
# /tmp/validation/washington/46.jpg: False, london
# /tmp/validation/washington/496.jpg: False, taipei
# /tmp/validation/washington/306.jpg: False, taipei
# /tmp/validation/washington/91.jpg: False, london
# /tmp/validation/washington/148.jpg: False, london
# /tmp/validation/washington/201.jpg: False, bangkok
# /tmp/validation/washington/93.jpg: False, bangkok
# /tmp/validation/washington/446.jpg: False, bangkok
# /tmp/validation/washington/266.jpg: False, london
# /tmp/validation/washington/267.jpg: False, london
# /tmp/validation/washington/68.jpg: False, taipei
